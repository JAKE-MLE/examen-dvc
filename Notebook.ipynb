# %%
import pandas as pd

# On définit le chemin (le séparateur / fonctionne sur WSL/Linux)
path = "data/raw/raw.csv"

# On charge les données
df = pd.read_csv(path)

display(df.shape)

# On affiche les premières lignes pour vérifier
display(df.head())
# Out:
# (1817, 10)
#                   date  ave_flot_air_flow  ave_flot_level  iron_feed  \
# 0  2017-04-24 00:00:00         300.263166      383.982443      55.17
# 1  2017-04-24 01:00:00         299.782402      386.049069      55.17
# 2  2017-04-24 02:00:00         299.750052      385.250935      55.17
# 3  2017-04-24 03:00:00         299.997522      389.635519      55.17
# 4  2017-04-24 04:00:00         300.005220      387.810807      55.17
#
#    starch_flow  amina_flow  ore_pulp_flow  ore_pulp_pH  ore_pulp_density  \
# 0  1979.589150  599.676489     400.017222     9.774028          1.753206
# 1  1758.466329  600.043100     400.484528     9.539246          1.754190
# 2  2379.752428  599.948406     400.325617     9.434227          1.756873
# 3  2287.130046  599.580383     399.801506     9.725607          1.727125
# 4  2291.789167  599.871217     399.567333     9.845198          1.633063
#
#    silica_concentrate
# 0            4.360000
# 1            3.290000
# 2            4.900000
# ...

# %%
import pandas as pd

# On définit le chemin (le séparateur / fonctionne sur WSL/Linux)
path = "data/raw/sales_20260302_1027.csv"


# On charge les données
df = pd.read_csv(path)

display(df.shape)

# On affiche les premières lignes pour vérifier
display(df.head())

# %%
import pandas as pd

# On définit le chemin (le séparateur / fonctionne sur WSL/Linux)
path = "data/raw/sales_20260302_0303.csv"

# On charge les données
df = pd.read_csv(path)

display(df.shape)

# On affiche les premières lignes pour vérifier
display(df.head())

# %%
import pandas as pd

# On définit le chemin (le séparateur / fonctionne sur WSL/Linux)
path = "data/processed/sales_processed_20260302_1028.csv"

# On charge les données
df = pd.read_csv(path)

display(df.shape)

# On affiche les premières lignes pour vérifier
display(df.head())

# %%
import pandas as pd

# On définit le chemin (le séparateur / fonctionne sur WSL/Linux)
path = "data/processed/sales_processed_20260302_0103.csv"

# On charge les données
df = pd.read_csv(path)

display(df.shape)

# On affiche les premières lignes pour vérifier
display(df.head())
